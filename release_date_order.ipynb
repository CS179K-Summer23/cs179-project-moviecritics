# %%
import pandas as pd
df = pd.read_csv("clean_data.csv")
df
# Out:
#         Unnamed: 0      id                                          title  \
# 0              152  785521                              Battle: Freestyle
# 1              163  949218                      S.O.S. Mamis: La película
# 2              164  928769                                    AI Love You
# 3              180  785521                              Battle: Freestyle
# 4              192  831223  Gone Mom: The Disappearance of Jennifer Dulos
# ...            ...     ...                                            ...
# 147388      722723  772891                                            408
# 147389      722734  869220                                      Quicksand
# 147390      722738  548760                            Wolves of the North
# 147391      722740  702248                                Weeping Shriner
# 147392      722744  912284                                          Smile
#
#                                 genres original_language  \
# ...

# %%
df_oldest= df
df_newest = df

# %%
df_oldest['release_date'] = pd.to_datetime(df.release_date, infer_datetime_format = True)
df_oldest.sort_values(by = 'release_date', ascending = True, inplace = True)
df_oldest[['title', 'release_date']].head(25)
# Out:
#                                               title release_date
# 115064                                 The Aquarium   1878-05-07
# 35776                                      The Kiss   1882-06-01
# 114818                     Woman Walking Downstairs   1887-01-01
# 32502                              Hyde Park Corner   1889-11-23
# 27686                                  Je Vous Aime   1891-01-01
# 131574                   Monkey and Another, Boxing   1891-01-01
# 27134                                      The Wave   1891-11-15
# 130231                                    Wrestling   1892-01-01
# 48274                                        Boxing   1892-01-01
# 137784                                      Rabbits   1893-02-01
# 51006                             Athlete with Wand   1894-02-01
# 70864                                Highland Dance   1894-04-01
# 90637                                  Buffalo Bill   1894-06-17
# ...

# %%
df_newest['release_date'] = pd.to_datetime(df.release_date, infer_datetime_format = True)
df_newest.sort_values(by = 'release_date', ascending = False, inplace = True)
df_newest[['title', 'release_date']].head(25)
# Out:
#                          title release_date
# 50396            The Wild Ones   2025-06-13
# 296             Fantastic Four   2025-02-12
# 51801              Son Göktürk   2025-01-01
# 8269                    Wicked   2024-12-25
# 290                      Blade   2024-09-04
# 1989                  Garfield   2024-05-24
# 19140                  Fighter   2024-01-25
# 4649                   Distant   2024-01-19
# 29702               Metro 2033   2024-01-01
# 18691               Metro 2033   2024-01-01
# 3180              Attraction 3   2024-01-01
# 122569                   Guilt   2023-12-31
# 21643                The Field   2023-12-31
# 71765                12 Chairs   2023-12-31
# 60495                Lifelines   2023-12-31
# 9696                   Anomaly   2023-12-31
# 41421              Before Dawn   2023-12-31
# 51466                   Escape   2023-12-31
# 35245                Ballerina   2023-12-31
# 65104    Guest from the Future   2023-12-28
# ...
